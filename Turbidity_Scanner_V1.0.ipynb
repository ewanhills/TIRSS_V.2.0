# %% [markdown]
# ## Algi Water Sample

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/algi_water_PICTURES_60/algi_water_1.jpg',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
plt.show()

# %% [markdown]
# ## Clay Water Sample

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/clay_water_PICTURES_60/clay_water_1.jpg',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
plt.show()

# %% [markdown]
# ## Clean Water Sample

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/clean_water_PICTURES_60/clean_water_1.jpg',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
plt.show()

# %% [markdown]
# ## Stream Sample

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/stream_water_PICTURES_60/stream_water_1.jpg',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
plt.show()

# %% [markdown]
# ## Iron Oxide Sample

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/iron_oxide_water_PICTURES_60/iron_oxide_water_2.jpg',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
plt.show()

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/iron_oxide_water_PICTURES_60/iron_oxide_water_3.jpg',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
plt.show()

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/iron_oxide_water_PICTURES_60/iron_oxide_water_4.jpg',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
plt.show()

# %% [markdown]
# ## Lime Water

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/lime_water_PICTURES_60/lime_water_1.jpg',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
plt.show()

# %% [markdown]
# #### Petrol_95_Octane

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/image_classification/petrol_octane95/petrol_octane98_01.jpg',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
plt.show()

# %% [markdown]
# #### Petrol_98_Octane

# %%
# importing required libraries of opencv
import cv2
  
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/image_classification/petrol_octane98/petrol_octane100_01.jpg',0)
  
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
  
# show the plotting graph of an image
plt.plot(histr)
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
plt.show()

# %% [markdown]
# ## Average Colour

# %% [markdown]
# #### Petrol_95_Octane

# %%
import cv2, numpy as np
from sklearn.cluster import KMeans

def visualize_colors(cluster, centroids):
    # Get the number of different clusters, create histogram, and normalize
    labels = np.arange(0, len(np.unique(cluster.labels_)) + 1)
    (hist, _) = np.histogram(cluster.labels_, bins = labels)
    hist = hist.astype("float")
    hist /= hist.sum()

    # Create frequency rect and iterate through each cluster's color and percentage
    rect = np.zeros((50, 300, 3), dtype=np.uint8)
    colors = sorted([(percent, color) for (percent, color) in zip(hist, centroids)])
    start = 0
    for (percent, color) in colors:
        print(color, "{:0.2f}%".format(percent * 100))
        end = start + (percent * 300)
        cv2.rectangle(rect, (int(start), 0), (int(end), 50), \
                      color.astype("uint8").tolist(), -1)
        start = end
    return rect

# Load image and convert to a list of pixels
image = cv2.imread('C:/Users/Fujitsu/Desktop/image_classification/petrol_octane95/petrol_octane98_01.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
reshape = image.reshape((image.shape[0] * image.shape[1], 3))

# Find and display most dominant colors
cluster = KMeans(n_clusters=5).fit(reshape)
visualize = visualize_colors(cluster, cluster.cluster_centers_)
visualize = cv2.cvtColor(visualize, cv2.COLOR_RGB2BGR)
cv2.imshow('visualize', visualize)
cv2.waitKey()
# Out:
# [218.05823419 215.74139011 201.46399499] 0.59%
# [77.38365063 84.91188127 71.04312689] 11.81%
# [49.17504764 65.79818325 57.3747599 ] 24.06%
# [17.42889122 26.58283503 18.23133582] 29.89%
# [32.37611997 46.03774778 38.02867348] 33.65%
# -1

# %% [markdown]
# #### Petrol_98_Octane

# %%
import cv2, numpy as np
from sklearn.cluster import KMeans

def visualize_colors(cluster, centroids):
    # Get the number of different clusters, create histogram, and normalize
    labels = np.arange(0, len(np.unique(cluster.labels_)) + 1)
    (hist, _) = np.histogram(cluster.labels_, bins = labels)
    hist = hist.astype("float")
    hist /= hist.sum()

    # Create frequency rect and iterate through each cluster's color and percentage
    rect = np.zeros((50, 300, 3), dtype=np.uint8)
    colors = sorted([(percent, color) for (percent, color) in zip(hist, centroids)])
    start = 0
    for (percent, color) in colors:
        print(color, "{:0.2f}%".format(percent * 100))
        end = start + (percent * 300)
        cv2.rectangle(rect, (int(start), 0), (int(end), 50), \
                      color.astype("uint8").tolist(), -1)
        start = end
    return rect

# Load image and convert to a list of pixels
image = cv2.imread('C:/Users/Fujitsu/Desktop/image_classification/petrol_octane98/petrol_octane100_01.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
reshape = image.reshape((image.shape[0] * image.shape[1], 3))

# Find and display most dominant colors
cluster = KMeans(n_clusters=5).fit(reshape)
visualize = visualize_colors(cluster, cluster.cluster_centers_)
visualize = cv2.cvtColor(visualize, cv2.COLOR_RGB2BGR)
cv2.imshow('visualize', visualize)
cv2.waitKey()
# Out:
# [221.8250472  218.10132159 205.49559471] 0.58%
# [73.39047115 80.43158465 69.23479204] 14.56%
# [45.34191559 62.51589996 54.72855765] 24.12%
# [14.1239202  23.43885776 18.11585987] 27.99%
# [29.9124493  41.0314893  35.65406646] 32.75%
# -1

# %% [markdown]
# ## Colour Spec Lime Water

# %%
import cv2, numpy as np
from sklearn.cluster import KMeans

def visualize_colors(cluster, centroids):
    # Get the number of different clusters, create histogram, and normalize
    labels = np.arange(0, len(np.unique(cluster.labels_)) + 1)
    (hist, _) = np.histogram(cluster.labels_, bins = labels)
    hist = hist.astype("float")
    hist /= hist.sum()

    # Create frequency rect and iterate through each cluster's color and percentage
    rect = np.zeros((50, 300, 3), dtype=np.uint8)
    colors = sorted([(percent, color) for (percent, color) in zip(hist, centroids)])
    start = 0
    for (percent, color) in colors:
        print(color, "{:0.2f}%".format(percent * 100))
        end = start + (percent * 300)
        cv2.rectangle(rect, (int(start), 0), (int(end), 50), \
                      color.astype("uint8").tolist(), -1)
        start = end
    return rect

# Load image and convert to a list of pixels
image = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/lime_water_PICTURES_60/lime_water_1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
reshape = image.reshape((image.shape[0] * image.shape[1], 3))

# Find and display most dominant colors
cluster = KMeans(n_clusters=5).fit(reshape)
visualize = visualize_colors(cluster, cluster.cluster_centers_)
visualize = cv2.cvtColor(visualize, cv2.COLOR_RGB2BGR)
cv2.imshow('visualize', visualize)
cv2.waitKey()
# Out:
# [ 0.07040045  5.58843354 34.65972336] 7.84%
# [ 43.30229267  99.39899403 211.89154287] 15.62%
# [ 0.30936392 25.20444775 92.33542004] 20.96%
# [  4.41551811  51.8633053  133.82615833] 27.42%
# [ 18.29312971  73.29000477 170.64346934] 28.16%
# -1

# %% [markdown]
# ## Color Spec Iron Oxide

# %%
import cv2, numpy as np
from sklearn.cluster import KMeans

def visualize_colors(cluster, centroids):
    # Get the number of different clusters, create histogram, and normalize
    labels = np.arange(0, len(np.unique(cluster.labels_)) + 1)
    (hist, _) = np.histogram(cluster.labels_, bins = labels)
    hist = hist.astype("float")
    hist /= hist.sum()

    # Create frequency rect and iterate through each cluster's color and percentage
    rect = np.zeros((50, 300, 3), dtype=np.uint8)
    colors = sorted([(percent, color) for (percent, color) in zip(hist, centroids)])
    start = 0
    for (percent, color) in colors:
        print(color, "{:0.2f}%".format(percent * 100))
        end = start + (percent * 300)
        cv2.rectangle(rect, (int(start), 0), (int(end), 50), \
                      color.astype("uint8").tolist(), -1)
        start = end
    return rect

# Load image and convert to a list of pixels
image = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/iron_oxide_water_PICTURES_60/iron_oxide_water_1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
reshape = image.reshape((image.shape[0] * image.shape[1], 3))

# Find and display most dominant colors
cluster = KMeans(n_clusters=5).fit(reshape)
visualize = visualize_colors(cluster, cluster.cluster_centers_)
visualize = cv2.cvtColor(visualize, cv2.COLOR_RGB2BGR)
cv2.imshow('visualize', visualize)
cv2.waitKey()
# Out:
# [124.85517573  99.75869042 185.05276842] 1.91%
# [ 82.01984367  54.26561479 108.33211529] 7.59%
# [55.19339686 28.93329016 68.02707453] 17.80%
# [29.34659404 18.15295028 45.98130113] 34.71%
# [ 9.18930296  8.49305277 19.44072261] 37.99%
# -1

# %% [markdown]
# ## Colour Spec Clay Water

# %%
import cv2, numpy as np
from sklearn.cluster import KMeans

def visualize_colors(cluster, centroids):
    # Get the number of different clusters, create histogram, and normalize
    labels = np.arange(0, len(np.unique(cluster.labels_)) + 1)
    (hist, _) = np.histogram(cluster.labels_, bins = labels)
    hist = hist.astype("float")
    hist /= hist.sum()

    # Create frequency rect and iterate through each cluster's color and percentage
    rect = np.zeros((50, 300, 3), dtype=np.uint8)
    colors = sorted([(percent, color) for (percent, color) in zip(hist, centroids)])
    start = 0
    for (percent, color) in colors:
        print(color, "{:0.2f}%".format(percent * 100))
        end = start + (percent * 300)
        cv2.rectangle(rect, (int(start), 0), (int(end), 50), \
                      color.astype("uint8").tolist(), -1)
        start = end
    return rect

# Load image and convert to a list of pixels
image = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/clay_water_PICTURES_60/clay_water_1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
reshape = image.reshape((image.shape[0] * image.shape[1], 3))

# Find and display most dominant colors
cluster = KMeans(n_clusters=10).fit(reshape)
visualize = visualize_colors(cluster, cluster.cluster_centers_)
visualize = cv2.cvtColor(visualize, cv2.COLOR_RGB2BGR)
cv2.imshow('Chromotogram', visualize)
cv2.waitKey()
# Out:
# [191.31271091 141.59167604 215.61079865] 0.16%
# [251.65511551 237.86221122 251.91171617] 0.22%
# [134.28641644  95.46738159 147.35120643] 0.41%
# [ 95.50580396  59.67863285 101.26698194] 0.85%
# [66.46232258 39.09212903 67.77458065] 1.42%
# [45.77383863 26.03978662 40.19170927] 3.30%
# [29.38616877 16.37511198 22.8322541 ] 7.17%
# [17.91449321 11.96669309 15.41422594] 19.92%
# [10.91257629  7.65572731  8.83472863] 31.56%
# [2.58408729 3.76911242 3.17097863] 34.97%
# -1

# %% [markdown]
# ## Colour Spec Algi

# %%
import cv2, numpy as np
from sklearn.cluster import KMeans

def visualize_colors(cluster, centroids):
    # Get the number of different clusters, create histogram, and normalize
    labels = np.arange(0, len(np.unique(cluster.labels_)) + 1)
    (hist, _) = np.histogram(cluster.labels_, bins = labels)
    hist = hist.astype("float")
    hist /= hist.sum()

    # Create frequency rect and iterate through each cluster's color and percentage
    rect = np.zeros((50, 300, 3), dtype=np.uint8)
    colors = sorted([(percent, color) for (percent, color) in zip(hist, centroids)])
    start = 0
    for (percent, color) in colors:
        print(color, "{:0.2f}%".format(percent * 100))
        end = start + (percent * 300)
        cv2.rectangle(rect, (int(start), 0), (int(end), 50), \
                      color.astype("uint8").tolist(), -1)
        start = end
    return rect

# Load image and convert to a list of pixels
image = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/algi_water_PICTURES_60/algi_water_1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
reshape = image.reshape((image.shape[0] * image.shape[1], 3))

# Find and display most dominant colors
cluster = KMeans(n_clusters=5).fit(reshape)
visualize = visualize_colors(cluster, cluster.cluster_centers_)
visualize = cv2.cvtColor(visualize, cv2.COLOR_RGB2BGR)
cv2.imshow('Chromotogram', visualize)
cv2.waitKey()
# Out:
# [235.91179713 223.73649394 235.84123484] 0.33%
# [105.25926482  79.21635409 114.31342836] 1.22%
# [43.34890511 39.00924574 51.38835593] 15.77%
# [21.92125792 20.80885032 27.76349657] 27.82%
# [ 7.4424381   8.97373722 10.17377678] 54.85%
# -1

# %% [markdown]
# ## Colour Spec Clear

# %%
import cv2, numpy as np
from sklearn.cluster import KMeans

def visualize_colors(cluster, centroids):
    # Get the number of different clusters, create histogram, and normalize
    labels = np.arange(0, len(np.unique(cluster.labels_)) + 1)
    (hist, _) = np.histogram(cluster.labels_, bins = labels)
    hist = hist.astype("float")
    hist /= hist.sum()

    # Create frequency rect and iterate through each cluster's color and percentage
    rect = np.zeros((50, 300, 3), dtype=np.uint8)
    colors = sorted([(percent, color) for (percent, color) in zip(hist, centroids)])
    start = 0
    for (percent, color) in colors:
        print(color, "{:0.2f}%".format(percent * 100))
        end = start + (percent * 300)
        cv2.rectangle(rect, (int(start), 0), (int(end), 50), \
                      color.astype("uint8").tolist(), -1)
        start = end
    return rect

# Load image and convert to a list of pixels
image = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/clean_water_PICTURES_60/clean_water_1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
reshape = image.reshape((image.shape[0] * image.shape[1], 3))

# Find and display most dominant colors
cluster = KMeans(n_clusters=5).fit(reshape)
visualize = visualize_colors(cluster, cluster.cluster_centers_)
visualize = cv2.cvtColor(visualize, cv2.COLOR_RGB2BGR)
cv2.imshow('Chromotogram', visualize)
cv2.waitKey()
# Out:
# [203.7694974  213.01169844 238.88518198] 0.42%
# [ 11.96159093  74.60037309 170.77306771] 13.23%
# [  8.00992006  46.65512186 123.6283798 ] 23.57%
# [ 0.7973426  10.05996705 46.41499176] 25.63%
# [ 2.65422742 24.21644586 84.07769965] 37.14%
# -1

# %% [markdown]
# ## Colour Spec Stream

# %%
import cv2, numpy as np
from sklearn.cluster import KMeans

def visualize_colors(cluster, centroids):
    # Get the number of different clusters, create histogram, and normalize
    labels = np.arange(0, len(np.unique(cluster.labels_)) + 1)
    (hist, _) = np.histogram(cluster.labels_, bins = labels)
    hist = hist.astype("float")
    hist /= hist.sum()

    # Create frequency rect and iterate through each cluster's color and percentage
    rect = np.zeros((50, 300, 3), dtype=np.uint8)
    colors = sorted([(percent, color) for (percent, color) in zip(hist, centroids)])
    start = 0
    for (percent, color) in colors:
        print(color, "{:0.2f}%".format(percent * 100))
        end = start + (percent * 300)
        cv2.rectangle(rect, (int(start), 0), (int(end), 50), \
                      color.astype("uint8").tolist(), -1)
        start = end
    return rect

# Load image and convert to a list of pixels
image = cv2.imread('C:/Users/Fujitsu/Desktop/image_classification/petrol_octane95/petrol_octane98_01.jpg')

image = cv2.imread('C:/Users/Fujitsu/Desktop/image_classification/petrol_octane98/petrol_octane100_01.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
reshape = image.reshape((image.shape[0] * image.shape[1], 3))

# Find and display most dominant colors
cluster = KMeans(n_clusters=5).fit(reshape)
visualize = visualize_colors(cluster, cluster.cluster_centers_)
visualize = cv2.cvtColor(visualize, cv2.COLOR_RGB2BGR)
cv2.imshow('Chromotogram', visualize)
cv2.waitKey()
# Out:
# [221.8445074  218.11614731 205.52817123] 0.58%
# [73.69441769 80.589629   69.28791206] 14.31%
# [45.60372057 62.9019066  55.18871478] 23.85%
# [14.27511949 23.61735494 18.35593874] 28.43%
# [30.29746729 41.43965894 35.92327873] 32.82%
# -1

# %%
import cv2 as cv
import numpy as np
from imageio import imread

image = imread('C:/Users/Fujitsu/Desktop/New_Samples/lime_water_PICTURES_60/lime_water_1.jpg')
img  = cv.cvtColor(np.array(image), cv.COLOR_RGB2BGR)
rows, cols, _ = img.shape

color_B = 0
color_G = 0
color_R = 0
color_N = 0 # neutral/gray color

for i in range(rows):
    for j in range(cols):
        k = img[i,j]
        if k[0] > k[1] and k[0] > k[2]:
            color_B = color_B + 1
            continue
        if k[1] > k[0] and k[1] > k[2]:
            color_G = color_G + 1
            continue        
        if k[2] > k[0] and k[2] > k[1]:
            color_R = color_R + 1
            continue
        color_N = color_N + 1

pix_total = rows * cols
print('Blue:', color_B/pix_total, 'Green:', color_G/pix_total, 'Red:',  color_R/pix_total, 'Gray:',  color_N/pix_total)
# Out:
# Blue: 1.0 Green: 0.0 Red: 0.0 Gray: 0.0

# %% [markdown]
# ## Mohit Example

# %%
from skimage import io
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
image = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/algi_water_PICTURES_60/algi_water_1.jpg')
image1 = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/clay_water_PICTURES_60/clay_water_1.jpg')
image2 = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/clean_water_PICTURES_60/clean_water_1.jpg')
image3 = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/lime_water_PICTURES_60/lime_water_1.jpg')
image4 = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/iron_oxide_water_PICTURES_60/iron_oxide_water_1.jpg')
image5 = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/stream_water_PICTURES_60/stream_water_1.jpg')

 

_ = plt.hist(image.ravel(), bins = 256, color = 'green')
_ = plt.hist(image1.ravel(), bins = 256, color = 'brown')
_ = plt.hist(image2.ravel(), bins = 256, color = 'blue')
_ = plt.hist(image3.ravel(), bins = 256, color = 'white')
_ = plt.hist(image4.ravel(), bins = 256, color = 'red')
_ = plt.hist(image5.ravel(), bins = 256, color = 'yellow',)


 

_ = plt.xlabel('Intensity Value')
_ = plt.ylabel('Count')
_ = plt.legend(['algi_water', 'clay_water', 'clean_water', 'lime_water', 'iron_oxide_water', 'stream_water'])
plt.show()

# %% [markdown]
# ## Ewans Hist of all samles in one

# %%
from skimage import io
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
image = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/algi_water_PICTURES_60/algi_water_1.jpg')
image1 = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/clay_water_PICTURES_60/clay_water_1.jpg')
image2 = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/clean_water_PICTURES_60/clean_water_1.jpg')
image3 = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/lime_water_PICTURES_60/lime_water_1.jpg')
image4 = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/iron_oxide_water_PICTURES_60/iron_oxide_water_1.jpg')
image5 = io.imread('C:/Users/Fujitsu/Desktop/New_Samples/stream_water_PICTURES_60/stream_water_1.jpg')

 

_ = plt.hist(image.ravel(), bins = 256, color = 'green')
_ = plt.hist(image1.ravel(), bins = 256, color = 'brown')
_ = plt.hist(image2.ravel(), bins = 256, color = 'blue')
_ = plt.hist(image3.ravel(), bins = 256, color = 'white')
_ = plt.hist(image4.ravel(), bins = 256, color = 'red')
_ = plt.hist(image5.ravel(), bins = 256, color = 'yellow',)


 
_ = plt.plot()
_ = plt.xlabel('Intensity Value')
_ = plt.ylabel('Count')
_ = plt.legend(['algi_water', 'clay_water', 'clean_water', 'lime_water', 'iron_oxide_water', 'stream_water'])
plt.show()

# %%
# importing required libraries of opencv
import cv2
from matplotlib import pyplot
# importing library for plotting
from matplotlib import pyplot as plt
  
# reads an input image
img = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/lime_water_PICTURES_60/lime_water_1.jpg',0)
img2 = cv2.imread('C:/Users/Fujitsu/Desktop/New_Samples/clay_water_PICTURES_60/clay_water_1.jpg',1)
# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])
histr2 = cv2.calcHist([img2],[1],None,[256],[0,256])
# show the plotting graph of an image
pyplot.hist(histr, label='x')
#pyplot.hist(histr2,label='y')
plt.legend(loc='upper right')
plt.ylim(0, 45000)
plt.xlabel('Brightness of Pixels')
plt.ylabel('Pixel Count Thousands')
pyplot.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('C:/Users/Fujitsu/Desktop/image_classification/petrol_octane95/petrol_octane98_01.jpg')
#img = np.zeros((200,200), np.uint8)
cv.rectangle(img, (0, 100), (200, 200), (255), -1)
cv.rectangle(img, (0, 50), (100, 100), (127), -1)
b, g, r = cv.split(img)
cv.imshow("img", img)
cv.imshow("b", b)
cv.imshow("g", g)
cv.imshow("r", r)

plt.hist(b.ravel(), 256, [0, 256])
plt.hist(g.ravel(), 256, [0, 256])
plt.hist(r.ravel(), 256, [0, 256])

hist = cv.calcHist([img], [0], None, [256], [0, 256])
plt.plot(hist)
plt.show()

cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('C:/Users/Fujitsu/Desktop/image_classification/petrol_octane98/petrol_octane100_01.jpg')
#img = np.zeros((200,200), np.uint8)
#cv.rectangle(img, (0, 100), (200, 200), (255), -1)
#cv.rectangle(img, (0, 50), (100, 100), (127), -1)
b, g, r = cv.split(img)
#cv.imshow("img", img)
#cv.imshow("b", b)
#cv.imshow("g", g)
#cv.imshow("r", r)

plt.hist(b.ravel(), 256, [0, 256])
plt.hist(g.ravel(), 256, [0, 256])
plt.hist(r.ravel(), 256, [0, 256])

hist = cv.calcHist([img], [0], None, [256], [0, 256])
plt.plot(hist)
plt.show()

#cv.waitKey(0)
#cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('C:/Users/Fujitsu/Desktop/New_Samples/clean_water_PICTURES_60/clean_water_1.jpg')
#img = np.zeros((200,200), np.uint8)
#cv.rectangle(img, (0, 100), (200, 200), (255), -1)
#cv.rectangle(img, (0, 50), (100, 100), (127), -1)
b, g, r = cv.split(img)
#cv.imshow("img", img)
#cv.imshow("b", b)
#cv.imshow("g", g)
#cv.imshow("r", r)

plt.hist(b.ravel(), 256, [0, 256])
plt.hist(g.ravel(), 256, [0, 256])
plt.hist(r.ravel(), 256, [0, 256])

hist = cv.calcHist([img], [0], None, [256], [0, 256])
plt.plot(hist)
plt.show()

#cv.waitKey(0)
#cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('C:/Users/Fujitsu/Desktop/New_Samples/stream_water_PICTURES_60/stream_water_1.jpg')
#img = np.zeros((200,200), np.uint8)
#cv.rectangle(img, (0, 100), (200, 200), (255), -1)
#cv.rectangle(img, (0, 50), (100, 100), (127), -1)
b, g, r = cv.split(img)
#cv.imshow("img", img)
#cv.imshow("b", b)
#cv.imshow("g", g)
#cv.imshow("r", r)

plt.hist(b.ravel(), 256, [0, 256])
plt.hist(g.ravel(), 256, [0, 256])
plt.hist(r.ravel(), 256, [0, 256])

hist = cv.calcHist([img], [0], None, [256], [0, 256])
plt.plot(hist)
plt.show()

#cv.waitKey(0)
#cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('C:/Users/Fujitsu/Desktop/image_classification/petrol_octane95/petrol_octane98_01.jpg')
#img = np.zeros((200,200), np.uint8)
#cv.rectangle(img, (0, 100), (200, 200), (255), -1)
#cv.rectangle(img, (0, 50), (100, 100), (127), -1)
b, g, r = cv.split(img)
#cv.imshow("img", img)
#cv.imshow("b", b)
#cv.imshow("g", g)
#cv.imshow("r", r)

plt.hist(b.ravel(), 256, [0, 256])
plt.hist(g.ravel(), 256, [0, 256])
plt.hist(r.ravel(), 256, [0, 256])

hist = cv.calcHist([img], [0], None, [256], [0, 256])
plt.plot(hist)
plt.show()

#cv.waitKey(0)
#cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('C:/Users/Fujitsu/Desktop/image_classification/petrol_octane98/petrol_octane100_01.jpg')
#img = np.zeros((200,200), np.uint8)
#cv.rectangle(img, (0, 100), (200, 200), (255), -1)
#cv.rectangle(img, (0, 50), (100, 100), (127), -1)
b, g, r = cv.split(img)
#cv.imshow("img", img)
#cv.imshow("b", b)
#cv.imshow("g", g)
#cv.imshow("r", r)

plt.hist(b.ravel(), 256, [0, 256])
plt.hist(g.ravel(), 256, [0, 256])
plt.hist(r.ravel(), 256, [0, 256])

hist = cv.calcHist([img], [0], None, [256], [0, 256])
plt.plot(hist)
plt.show()

#cv.waitKey(0)
#cv.destroyAllWindows()
